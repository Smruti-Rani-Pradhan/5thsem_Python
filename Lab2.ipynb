# %%
#Q12
import math
r=float(input("Enter the radius:"))
print("Area of circle:",math.pi*pow(r,2))
print("volume of Sphere:",(4/3)*math.pi*pow(r,3))
# Out:
# Enter the radius:4
# Area of circle: 50.26548245743669
# volume of Sphere: 268.082573106329

# %%
#Q13
n=int(input("Enter a number:")) 
print("Sum of n numbers:",n*(n+1)//2)
# Out:
# Enter a number:5
# Sum of n numbers: 15

# %%
#Q15 
p=1000;
r=0.12;
# n=int(input("no. of the years:"))
a=p*pow((1+r),10)
print("Amount After 10 years:",a)
a=p*pow((1+r),20)
print("Amount After 20 years:",a)
a=p*pow((1+r),30)
print("Amount After 30 years:",a)
# Out:
# Amount After 10 years: 3105.8482083442123
# Amount After 20 years: 9646.293093274951
# Amount After 30 years: 29959.92212091116

# %%
import math
e=math.e
p=math.pi
print(pow(e,p)," ",pow(p,e))
if pow(e,p)>pow(p,e):
    print("okay")
else:
    print("Okay anyway")
# Out:
# 23.140692632779263   22.45915771836104
# okay
